# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul1234500/python/blob/main/basics/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Rahul"
print(name)
# Out:
# Rahul

# %%
age = 23 # store integer value
print(f"age is {age}")
# Out:
# age is 23
