# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul1234500/python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Rahul Kale Software Developer")
# Out:
# Rahul Kale Software Developer
