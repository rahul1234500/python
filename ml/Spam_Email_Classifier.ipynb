# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul1234500/python/blob/main/ml/Spam_Email_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Spam Email Classifier")
# Out:
# Spam Email Classifier
