# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul1234500/python/blob/main/ml/student_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd

data = {
    "hours" : [1,2,3,4,5,6,7,8] ,
    "marks": [15,18,35,38,52,65,68,85]
}

df = pd.DataFrame(data)
df
# Out:
#    hours  marks
# 0      1     15
# 1      2     18
# 2      3     35
# 3      4     38
# 4      5     52
# 5      6     65
# 6      7     68
# 7      8     85

# %%
df.head()
# Out:
#    hours  marks
# 0      1     15
# 1      2     18
# 2      3     35
# 3      4     38
# 4      5     52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   hours   8 non-null      int64
#  1   marks   8 non-null      int64
# dtypes: int64(2)
# memory usage: 260.0 bytes

# %%
df.describe()
# Out:
#          hours      marks
# count  8.00000   8.000000
# mean   4.50000  47.000000
# std    2.44949  24.853859
# min    1.00000  15.000000
# 25%    2.75000  30.750000
# 50%    4.50000  45.000000
# 75%    6.25000  65.750000
# max    8.00000  85.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df['hours'], df['marks'] )
plt.xlabel("Study Hours")
plt.ylabel("Study Hours vs Marks")
plt.title("Study Hours vs Marks")
plt.show()
